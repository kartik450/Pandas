# %% [markdown]
# <h1 style="text-align:center; color:red">Pandas</h1>

# %% [markdown]
# <h2 style="color:green">Pandas is a Python library used for data manipulation and analysis, offering powerful data structures like DataFrame and Series. It is widely used for tasks such as cleaning, transforming, and analyzing structured data.</h2>

# %%
pip install pandas #installing pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Invalid requirement: '#installing'

# %%
import pandas as pd

# %%
dt={"Name":["Priyanshi","Kartik","Ronak"],
    "Branch":["it","ai","it"],
    "class":[1,2,3],
    "city":["Sikar","Copper","Pilani"]
    }
dt
# Out:
# {'Name': ['Priyanshi', 'Kartik', 'Ronak'],
#  'Branch': ['it', 'ai', 'it'],
#  'class': [1, 2, 3],
#  'city': ['Sikar', 'Copper', 'Pilani']}

# %%
df=pd.DataFrame(dt) ## creating DataFrame from dictionary
df
# Out:
#         Name Branch  class    city
# 0  Priyanshi     it      1   Sikar
# 1     Kartik     ai      2  Copper
# 2      Ronak     it      3  Pilani

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df["Name"] ##accessing column
# Out:
# 0    Priyanshi
# 1       Kartik
# 2        Ronak
# Name: Name, dtype: object

# %%
type(df["Name"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Perform operation upon csv file.

# %%
df=pd.read_csv("Used_Bikes.csv") ## reading a csv file
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.head()# head returns top 5 rows by default
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df.tail() #(34) # tail returns by deafult last 5 lines
# Out:
#                        bike_name    price    city  kms_driven        owner  \
# 32643     Hero Passion Pro 100cc  39000.0   Delhi     22000.0  First Owner
# 32644       TVS Apache RTR 180cc  30000.0  Karnal      6639.0  First Owner
# 32645   Bajaj Avenger Street 220  60000.0   Delhi     20373.0  First Owner
# 32646  Hero Super Splendor 125cc  15600.0  Jaipur     84186.0  First Owner
# 32647         Bajaj Pulsar 150cc  22000.0    Pune     60857.0  First Owner
#
#         age  power  brand
# 32643   4.0  100.0   Hero
# 32644   9.0  180.0    TVS
# 32645   6.0  220.0  Bajaj
# 32646  16.0  125.0   Hero
# 32647  13.0  150.0  Bajaj

# %%
print(df.info()) #returns information of database
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  object
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB
# None

# %% [markdown]
# #Accessing

# %%
df.price #accessing "price" column
# Out:
# 0         35000.0
# 1        119900.0
# 2        600000.0
# 3         65000.0
# 4         80000.0
#            ...
# 32643     39000.0
# 32644     30000.0
# 32645     60000.0
# 32646     15600.0
# 32647     22000.0
# Name: price, Length: 32648, dtype: float64

# %%
df['price']#accessing "price" column
# Out:
# 0         35000.0
# 1        119900.0
# 2        600000.0
# 3         65000.0
# 4         80000.0
#            ...
# 32643     39000.0
# 32644     30000.0
# 32645     60000.0
# 32646     15600.0
# 32647     22000.0
# Name: price, Length: 32648, dtype: float64

# %%
df[['price']] # converting price column in form of dataframe
# Out:
#           price
# 0       35000.0
# 1      119900.0
# 2      600000.0
# 3       65000.0
# 4       80000.0
# ...         ...
# 32643   39000.0
# 32644   30000.0
# 32645   60000.0
# 32646   15600.0
# 32647   22000.0
#
# [32648 rows x 1 columns]

# %%
df[['price','city','brand']] #returns all columns included
# Out:
#           price       city          brand
# 0       35000.0  Ahmedabad            TVS
# 1      119900.0      Delhi  Royal Enfield
# 2      600000.0      Delhi        Triumph
# 3       65000.0  Bangalore            TVS
# 4       80000.0  Bangalore         Yamaha
# ...         ...        ...            ...
# 32643   39000.0      Delhi           Hero
# 32644   30000.0     Karnal            TVS
# 32645   60000.0      Delhi          Bajaj
# 32646   15600.0     Jaipur           Hero
# 32647   22000.0       Pune          Bajaj
#
# [32648 rows x 3 columns]

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
#LOC and ILOC ## used to access data from dataframe locationwise

# %%
df.loc[101:111] ##returns data from line 101 to 111. (111 will be included)
# Out:
#                                bike_name     price       city  kms_driven  \
# 101                   Bajaj Pulsar RS200   80000.0  Bangalore     26691.0
# 102          Royal Enfield Classic 350cc  135000.0  Bangalore     45000.0
# 103                   Bajaj Pulsar 150cc   11100.0       Pune     12000.0
# 104                     Benelli TNT 600i  480000.0     Mumbai     14200.0
# 105     Suzuki Gixxer 150cc SP Rear Disc   65000.0   Thrissur     41000.0
# 106              Yamaha FZ S V 2.0 150cc   60000.0  Bangalore     15000.0
# 107                 Honda CBR 150R 150cc   80000.0  Bangalore     12314.0
# 108  Hero Splendor Plus Self Alloy 100cc   46000.0      Delhi     11760.0
# 109          Royal Enfield Classic 500cc   95000.0  Bangalore     22000.0
# 110                       Hyosung GT650R  400000.0      Delhi      1800.0
# 111                      Bajaj V15 150cc   55000.0  Bangalore      4400.0
#
#            owner   age  power          brand
# ...

# %%
df.loc[10:20,["price","city"]] # here in loc, we can't give column numbers, we have to give their names.
# Out:
#        price       city
# 10   72000.0  Bangalore
# 11   95000.0  Bangalore
# 12   78000.0  Bangalore
# 13   29499.0      Delhi
# 14   29900.0      Delhi
# 15   90000.0  Bangalore
# 16  120000.0  Bangalore
# 17   48000.0     Mumbai
# 18  240000.0     Mumbai
# 19   29900.0      Delhi
# 20  120000.0  Bangalore

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.loc[20:35,["owner","age","power","brand"]] ## accessing 4 columns from row 20 to 35.
# Out:
#            owner   age  power          brand
# 20   First Owner   3.0  200.0          Bajaj
# 21   First Owner   5.0  150.0         Suzuki
# 22   First Owner   2.0  110.0           Hero
# 23   First Owner   5.0  500.0  Royal Enfield
# 24   First Owner   6.0  150.0         Yamaha
# 25   First Owner   4.0  200.0          Bajaj
# 26   First Owner  16.0  125.0           Hero
# 27  Second Owner   7.0  125.0          Honda
# 28   First Owner   8.0  150.0          Bajaj
# 29   First Owner   2.0  160.0          Honda
# 30   First Owner   3.0  200.0          Bajaj
# 31  Second Owner   4.0  150.0         Yamaha
# 32   First Owner   6.0  220.0          Bajaj
# 33   First Owner   4.0  390.0            KTM
# 34   First Owner   8.0  150.0          Honda
# 35  Second Owner   8.0  200.0            KTM

# %%
df.iloc[0:25,0:1] #In iloc, we can give indexing to both rows and columns.
# it will exclude row 25.
# Out:
#                                    bike_name
# 0         TVS Star City Plus Dual Tone 110cc
# 1                Royal Enfield Classic 350cc
# 2                       Triumph Daytona 675R
# 3                       TVS Apache RTR 180cc
# 4       Yamaha FZ S V 2.0 150cc-Ltd. Edition
# 5                           Yamaha FZs 150cc
# 6              Honda CB Hornet 160R  ABS DLX
# 7        Hero Splendor Plus Self Alloy 100cc
# 8          Royal Enfield Thunderbird X 350cc
# 9   Royal Enfield Classic Desert Storm 500cc
# 10                  Yamaha YZF-R15 2.0 150cc
# 11                         Yamaha FZ25 250cc
# 12                        Bajaj Pulsar NS200
# 13                       Bajaj Discover 100M
# 14                       Bajaj Discover 125M
# 15                    Bajaj Pulsar NS200 ABS
# 16                    Bajaj Pulsar RS200 ABS
# 17                    Suzuki Gixxer SF 150cc
# 18                        Benelli 302R 300CC
# 19                       Bajaj Discover 125M
# ...

# %%
df['price'].median() ## returns median of 'price' column.
# Out:
# 43000.0

# %%
print(df.columns) ##prints name of all columns
# Out:
# Index(['bike_name', 'price', 'city', 'kms_driven', 'owner', 'age', 'power',
#        'brand'],
#       dtype='object')

# %%
df.columns=['bike_name', 'price', 'city', 'kms_driven', 'owner', 'bike_age', 'power',
       'brand'] ## renaming columns manually.

# %%
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  bike_age  power          brand
# 0  First Owner       3.0  110.0            TVS
# 1  First Owner       4.0  350.0  Royal Enfield
# 2  First Owner       8.0  675.0        Triumph
# 3  First Owner       4.0  180.0            TVS
# 4  First Owner       3.0  150.0         Yamaha

# %%
df.shape ## returns number of rows and columns
# Out:
# (32648, 8)

# %%
df.dtypes##returns data type of all columns
# Out:
# bike_name      object
# price         float64
# city           object
# kms_driven    float64
# owner          object
# bike_age      float64
# power         float64
# brand          object
# dtype: object

# %%
under_50k=df[df["price"]<=50000] # filtering data 
under_50k
#under_50k contains data of bikes under 50000 price
# Out:
#                                  bike_name    price         city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc  35000.0    Ahmedabad     17654.0
# 7      Hero Splendor Plus Self Alloy 100cc  45000.0        Delhi     12645.0
# 13                     Bajaj Discover 100M  29499.0        Delhi     20000.0
# 14                     Bajaj Discover 125M  29900.0        Delhi     20000.0
# 17                  Suzuki Gixxer SF 150cc  48000.0       Mumbai     24725.0
# ...                                    ...      ...          ...         ...
# 32642                   Hero Passion 100cc  15000.0  Perumbavoor     35000.0
# 32643               Hero Passion Pro 100cc  39000.0        Delhi     22000.0
# 32644                 TVS Apache RTR 180cc  30000.0       Karnal      6639.0
# 32646            Hero Super Splendor 125cc  15600.0       Jaipur     84186.0
# 32647                   Bajaj Pulsar 150cc  22000.0         Pune     60857.0
#
#               owner  bike_age  power   brand
# ...

# %%
print(under_50k.shape)#returns number of rows and columns.
# Out:
# (19114, 8)

# %%
under_50k['brand'].value_counts() #returns name of brands with number of items
# Out:
# brand
# Bajaj            7143
# Hero             6258
# Yamaha           2250
# Suzuki           1295
# Honda            1178
# TVS               936
# Mahindra           31
# Royal Enfield      22
# LML                 1
# Name: count, dtype: int64

# %%
under_50k["owner"].value_counts() #return all owners with number.
# Out:
# owner
# First Owner             17447
# Second Owner             1604
# Third Owner                57
# Fourth Owner Or More        6
# Name: count, dtype: int64

# %%
under_50k_first=under_50k[under_50k['owner']=="First Owner"] ## filtering out first owner

# %%
under_50k_first.head(10)
# Out:
#                               bike_name    price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc  35000.0  Ahmedabad     17654.0
# 7   Hero Splendor Plus Self Alloy 100cc  45000.0      Delhi     12645.0
# 13                  Bajaj Discover 100M  29499.0      Delhi     20000.0
# 14                  Bajaj Discover 125M  29900.0      Delhi     20000.0
# 17               Suzuki Gixxer SF 150cc  48000.0     Mumbai     24725.0
# 19                  Bajaj Discover 125M  29900.0      Delhi     20000.0
# 21               Suzuki Gixxer SF 150cc  48000.0     Mumbai     24725.0
# 22  Hero Splendor iSmart Plus IBS 110cc  46500.0      Delhi      3500.0
# 24                Yamaha FZ V 2.0 150cc  45000.0      Delhi     23000.0
# 26            Hero Super Splendor 125cc  20000.0  Ahmedabad     29305.0
#
#           owner  bike_age  power   brand
# 0   First Owner       3.0  110.0     TVS
# 7   First Owner       3.0  100.0    Hero
# 13  First Owner       8.0  100.0   Bajaj
# ...

# %%
under_50k_first.min() ## returns minimum values from dataframe "under_50k_first"
# Out:
# bike_name     Bajaj  Pulsar 180cc
# price                      4400.0
# city                   24 Pargana
# kms_driven                   22.0
# owner                 First Owner
# bike_age                      2.0
# power                       100.0
# brand                       Bajaj
# dtype: object

# %%
under_50k_first["brand"].value_counts()
# Out:
# brand
# Bajaj            6356
# Hero             5541
# Yamaha           2187
# Suzuki           1286
# Honda            1131
# TVS               905
# Mahindra           27
# Royal Enfield      13
# LML                 1
# Name: count, dtype: int64

# %%
under_50k_first['brand'].unique() #returns item name single time
# Out:
# array(['TVS', 'Hero', 'Bajaj', 'Suzuki', 'Yamaha', 'Honda', 'Mahindra',
#        'Royal Enfield', 'LML'], dtype=object)

# %%
under_50k_first["brand"].nunique()#returns number of unique items
# Out:
# 9

# %%
df["brand"].nunique()
# Out:
# 23

# %%
df["brand"].unique()
# Out:
# array(['TVS', 'Royal Enfield', 'Triumph', 'Yamaha', 'Honda', 'Hero',
#        'Bajaj', 'Suzuki', 'Benelli', 'KTM', 'Mahindra', 'Kawasaki',
#        'Ducati', 'Hyosung', 'Harley-Davidson', 'Jawa', 'BMW', 'Indian',
#        'Rajdoot', 'LML', 'Yezdi', 'MV', 'Ideal'], dtype=object)

# %%
df[(df["price"]<=100000) & (df["owner"]=="First Owner") & (df["bike_age"]<=2)] ##filtering out data by certain conditions
# Out:
#                                 bike_name    price       city  kms_driven  \
# 22    Hero Splendor iSmart Plus IBS 110cc  46500.0      Delhi      3500.0
# 29                Honda X-Blade 160CC ABS  81200.0     Mettur      9100.0
# 47             Mahindra Centuro NXT 110cc  28000.0     Jaipur     45000.0
# 95                     Bajaj Pulsar 150cc  60000.0       Pune      2000.0
# 96             Suzuki Gixxer Fi 150cc ABS  96700.0   Vadodara      5100.0
# ...                                   ...      ...        ...         ...
# 8335              Bajaj Pulsar 150cc Neon  72000.0       Pune      3162.0
# 8531                 Hero Xtreme 200R ABS  85000.0  Bangalore        40.0
# 8536               Hero Glamour i3s 125cc  75000.0    Gurgaon      7488.0
# 8796                 Hero Xtreme 200R ABS  85000.0  Bangalore        40.0
# 9322            TVS Radeon 110cc Drum SBT  58000.0      Delhi      4020.0
#
#             owner  bike_age  power     brand
# ...

# %%
df[(df["price"]<=100000) & (df["owner"]=="First Owner") & (df["bike_age"]<=2) & (df["brand"]=="Bajaj")].count() ## return number of item in filtered data
# Out:
# bike_name     41
# price         41
# city          41
# kms_driven    41
# owner         41
# bike_age      41
# power         41
# brand         41
# dtype: int64

# %% [markdown]
# Day 2

# %%
df=pd.read_csv("Used_Bikes.csv")
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.dtypes #returns data type of columns
# Out:
# bike_name      object
# price         float64
# city           object
# kms_driven    float64
# owner          object
# age           float64
# power         float64
# brand          object
# dtype: object

# %%
df[['price','kms_driven','age','power']] # separating numerical columns manually
# Out:
#           price  kms_driven   age  power
# 0       35000.0     17654.0   3.0  110.0
# 1      119900.0     11000.0   4.0  350.0
# 2      600000.0       110.0   8.0  675.0
# 3       65000.0     16329.0   4.0  180.0
# 4       80000.0     10000.0   3.0  150.0
# ...         ...         ...   ...    ...
# 32643   39000.0     22000.0   4.0  100.0
# 32644   30000.0      6639.0   9.0  180.0
# 32645   60000.0     20373.0   6.0  220.0
# 32646   15600.0     84186.0  16.0  125.0
# 32647   22000.0     60857.0  13.0  150.0
#
# [32648 rows x 4 columns]

# %%
df.select_dtypes(include="O") #include those whose data type is object(String)
# Out:
#                                   bike_name       city        owner  \
# 0        TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner
# 1               Royal Enfield Classic 350cc      Delhi  First Owner
# 2                      Triumph Daytona 675R      Delhi  First Owner
# 3                      TVS Apache RTR 180cc  Bangalore  First Owner
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore  First Owner
# ...                                     ...        ...          ...
# 32643                Hero Passion Pro 100cc      Delhi  First Owner
# 32644                  TVS Apache RTR 180cc     Karnal  First Owner
# 32645              Bajaj Avenger Street 220      Delhi  First Owner
# 32646             Hero Super Splendor 125cc     Jaipur  First Owner
# 32647                    Bajaj Pulsar 150cc       Pune  First Owner
#
#                brand
# 0                TVS
# 1      Royal Enfield
# 2            Triumph
# 3                TVS
# 4             Yamaha
# ...

# %%
catgorical= df.select_dtypes(include="O") #include object type data
catgorical
# Out:
#                                   bike_name       city        owner  \
# 0        TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner
# 1               Royal Enfield Classic 350cc      Delhi  First Owner
# 2                      Triumph Daytona 675R      Delhi  First Owner
# 3                      TVS Apache RTR 180cc  Bangalore  First Owner
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore  First Owner
# ...                                     ...        ...          ...
# 32643                Hero Passion Pro 100cc      Delhi  First Owner
# 32644                  TVS Apache RTR 180cc     Karnal  First Owner
# 32645              Bajaj Avenger Street 220      Delhi  First Owner
# 32646             Hero Super Splendor 125cc     Jaipur  First Owner
# 32647                    Bajaj Pulsar 150cc       Pune  First Owner
#
#                brand
# 0                TVS
# 1      Royal Enfield
# 2            Triumph
# 3                TVS
# 4             Yamaha
# ...

# %%
numerical=df.select_dtypes(exclude="O") ##exclude object type data. Including only numerical data.
numerical.head()
# Out:
#       price  kms_driven  age  power
# 0   35000.0     17654.0  3.0  110.0
# 1  119900.0     11000.0  4.0  350.0
# 2  600000.0       110.0  8.0  675.0
# 3   65000.0     16329.0  4.0  180.0
# 4   80000.0     10000.0  3.0  150.0

# %%
new_data=pd.concat([catgorical,numerical],axis='columns') # adding both dataframes
new_data.head(2)
# Out:
#                             bike_name       city        owner          brand  \
# 0  TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner            TVS
# 1         Royal Enfield Classic 350cc      Delhi  First Owner  Royal Enfield
#
#       price  kms_driven  age  power
# 0   35000.0     17654.0  3.0  110.0
# 1  119900.0     11000.0  4.0  350.0

# %%
catgorical.shape
# Out:
# (32648, 4)

# %%
numerical.shape
# Out:
# (32648, 4)

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.drop('bike_name',axis='columns') # to delelte column from dataframe but changes will not save in df
# Out:
#           price       city  kms_driven        owner   age  power  \
# 0       35000.0  Ahmedabad     17654.0  First Owner   3.0  110.0
# 1      119900.0      Delhi     11000.0  First Owner   4.0  350.0
# 2      600000.0      Delhi       110.0  First Owner   8.0  675.0
# 3       65000.0  Bangalore     16329.0  First Owner   4.0  180.0
# 4       80000.0  Bangalore     10000.0  First Owner   3.0  150.0
# ...         ...        ...         ...          ...   ...    ...
# 32643   39000.0      Delhi     22000.0  First Owner   4.0  100.0
# 32644   30000.0     Karnal      6639.0  First Owner   9.0  180.0
# 32645   60000.0      Delhi     20373.0  First Owner   6.0  220.0
# 32646   15600.0     Jaipur     84186.0  First Owner  16.0  125.0
# 32647   22000.0       Pune     60857.0  First Owner  13.0  150.0
#
#                brand
# 0                TVS
# 1      Royal Enfield
# 2            Triumph
# 3                TVS
# 4             Yamaha
# ...              ...
# 32643           Hero
# ...

# %%
df.drop('bike_name',axis='columns',inplace=True) #inplace will save changes in dataframe
df
# Out:
#           price       city  kms_driven        owner   age  power  \
# 0       35000.0  Ahmedabad     17654.0  First Owner   3.0  110.0
# 1      119900.0      Delhi     11000.0  First Owner   4.0  350.0
# 2      600000.0      Delhi       110.0  First Owner   8.0  675.0
# 3       65000.0  Bangalore     16329.0  First Owner   4.0  180.0
# 4       80000.0  Bangalore     10000.0  First Owner   3.0  150.0
# ...         ...        ...         ...          ...   ...    ...
# 32643   39000.0      Delhi     22000.0  First Owner   4.0  100.0
# 32644   30000.0     Karnal      6639.0  First Owner   9.0  180.0
# 32645   60000.0      Delhi     20373.0  First Owner   6.0  220.0
# 32646   15600.0     Jaipur     84186.0  First Owner  16.0  125.0
# 32647   22000.0       Pune     60857.0  First Owner  13.0  150.0
#
#                brand
# 0                TVS
# 1      Royal Enfield
# 2            Triumph
# 3                TVS
# 4             Yamaha
# ...              ...
# 32643           Hero
# ...

# %%
df=pd.read_csv("Used_Bikes.csv")

# %%
# to add column in dataframe 
df['dummy']="upflairs" #with scalar value or single value in column
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df['fake_price']=df['price']+1000 #add one thousand to price and store in fake_price column
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df['dummy']="upflairs"
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.drop(["fake_price","dummy"],axis="columns",inplace=True) ##removing 2 columns
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df[df['brand']=="KTM"].shape ## returns number of rows and columns
# Out:
# (1077, 8)

# %%
df.duplicated().sum() ##return duplicates
# Out:
# 25324

# %%
df.drop_duplicates(inplace=True) ## to delete duplicate items from dataframe

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [bike_name, price, city, kms_driven, owner, age, power, brand]
# Index: []

# %%
new_data[new_data.duplicated()]
# Out:
#                              bike_name       city        owner          brand  \
# 19                 Bajaj Discover 125M      Delhi  First Owner          Bajaj
# 20              Bajaj Pulsar RS200 ABS  Bangalore  First Owner          Bajaj
# 21              Suzuki Gixxer SF 150cc     Mumbai  First Owner         Suzuki
# 25                  Bajaj Pulsar NS200  Bangalore  First Owner          Bajaj
# 90     Royal Enfield Thunderbird 350cc     Mumbai  First Owner  Royal Enfield
# ...                                ...        ...          ...            ...
# 32643           Hero Passion Pro 100cc      Delhi  First Owner           Hero
# 32644             TVS Apache RTR 180cc     Karnal  First Owner            TVS
# 32645         Bajaj Avenger Street 220      Delhi  First Owner          Bajaj
# 32646        Hero Super Splendor 125cc     Jaipur  First Owner           Hero
# 32647               Bajaj Pulsar 150cc       Pune  First Owner          Bajaj
#
# ...

# %%
df['brand'].value_counts() ##returns brand name with number of items
# Out:
# brand
# Bajaj              2081
# Royal Enfield      1346
# Hero               1142
# Honda               676
# Yamaha              651
# TVS                 481
# KTM                 375
# Suzuki              203
# Harley-Davidson      91
# Kawasaki             61
# Hyosung              53
# Mahindra             50
# Benelli              46
# Triumph              21
# Ducati               20
# BMW                  10
# Jawa                  7
# Indian                3
# MV                    3
# Rajdoot               1
# LML                   1
# Yezdi                 1
# Ideal                 1
# Name: count, dtype: int64

# %%
filter_df=df[(df['brand']=="KTM") | (df['brand']=="Suzuki") | (df['brand']=="Jawa")] ##filtering data by multiple conditions
filter_df
# Out:
#                              bike_name     price       city  kms_driven  \
# 17              Suzuki Gixxer SF 150cc   48000.0     Mumbai     24725.0
# 33                        KTM RC 390cc  180000.0       Pune     17700.0
# 35                      KTM Duke 200cc   70000.0     Nashik    100000.0
# 39                    KTM RC 200cc ABS  179000.0  Bangalore      3400.0
# 49    Suzuki Gixxer SF Fi 150cc SP ABS   97000.0      Delhi      4400.0
# ...                                ...       ...        ...         ...
# 9195                    KTM Duke 200cc   70000.0      Thane     49347.0
# 9255                    KTM Duke 125cc  135000.0  Bangalore      1050.0
# 9281  Suzuki Gixxer SF 150cc Rear Disc   63000.0  Bangalore     19100.0
# 9282                    KTM Duke 390cc  139100.0      Delhi     25500.0
# 9348                    KTM Duke 390cc  195000.0     Mumbai      4568.0
#
#              owner  age  power   brand
# 17     First Owner  5.0  150.0  Suzuki
# ...

# %%
brand_ls=["KTM","Suzuki","Jawa"]
df[df["brand"].isin(brand_ls)] # Same as filter_df
# Out:
#                              bike_name     price       city  kms_driven  \
# 17              Suzuki Gixxer SF 150cc   48000.0     Mumbai     24725.0
# 33                        KTM RC 390cc  180000.0       Pune     17700.0
# 35                      KTM Duke 200cc   70000.0     Nashik    100000.0
# 39                    KTM RC 200cc ABS  179000.0  Bangalore      3400.0
# 49    Suzuki Gixxer SF Fi 150cc SP ABS   97000.0      Delhi      4400.0
# ...                                ...       ...        ...         ...
# 9195                    KTM Duke 200cc   70000.0      Thane     49347.0
# 9255                    KTM Duke 125cc  135000.0  Bangalore      1050.0
# 9281  Suzuki Gixxer SF 150cc Rear Disc   63000.0  Bangalore     19100.0
# 9282                    KTM Duke 390cc  139100.0      Delhi     25500.0
# 9348                    KTM Duke 390cc  195000.0     Mumbai      4568.0
#
#              owner  age  power   brand
# 17     First Owner  5.0  150.0  Suzuki
# ...

# %%
brand_lst=["Mumbai","Pune","Nashik"]
filter_df[filter_df["city"].isin(brand_lst)] ##filtering data according to list
# Out:
#                    bike_name     price    city  kms_driven         owner  age  \
# 17    Suzuki Gixxer SF 150cc   48000.0  Mumbai     24725.0   First Owner  5.0
# 33              KTM RC 390cc  180000.0    Pune     17700.0   First Owner  4.0
# 35            KTM Duke 200cc   70000.0  Nashik    100000.0  Second Owner  8.0
# 199           KTM Duke 200cc   85000.0  Mumbai     15000.0   First Owner  7.0
# 249           KTM Duke 200cc   87000.0  Mumbai     20000.0   First Owner  6.0
# ...                      ...       ...     ...         ...           ...  ...
# 8661          KTM Duke 390cc  135000.0    Pune      8823.0   First Owner  5.0
# 8974            KTM RC 390cc  165000.0    Pune     26000.0   First Owner  5.0
# 8983     Suzuki Gixxer 150cc   58000.0  Mumbai      6000.0   First Owner  5.0
# 9034          KTM Duke 200cc   95000.0  Mumbai     20000.0   First Owner  6.0
# 9348          KTM Duke 390cc  195000.0  Mumbai      4568.0   First Owner  4.0
#
#       power   brand
# ...

# %%
jaip=df[df["city"]=="Jaipur"]

# %%
jaip[jaip["brand"]=="KTM"].count() ##returns number of KTM bikes in japiur
# Out:
# bike_name     7
# price         7
# city          7
# kms_driven    7
# owner         7
# age           7
# power         7
# brand         7
# dtype: int64

# %%
brand_ls=["KTM","TVS","Suzuki"]
jaipur_bike=jaip[jaip["brand"].isin(brand_ls)]

# %%
bike_70k=jaipur_bike[jaipur_bike['price']<=70000] #filtering data

# %%
bike_70k[(bike_70k['owner']=="First Owner") & (bike_70k['age']<=2) & (bike_70k['power']<=180)]
# Out:
#                  bike_name    price    city  kms_driven        owner  age  \
# 7311  TVS Apache RTR 180cc  70000.0  Jaipur    207102.0  First Owner  2.0
#
#       power brand
# 7311  180.0   TVS

# %%
jaip.sort_values(by='price') #sorting data by price
# Out:
#                            bike_name      price    city  kms_driven  \
# 2696         Hero Passion Plus 100cc    14000.0  Jaipur     70756.0
# 9029              Hero Passion 100cc    14000.0  Jaipur     50000.0
# 3365       Hero Super Splendor 125cc    15000.0  Jaipur     52391.0
# 2983              Bajaj CT 100 100cc    15000.0  Jaipur     48000.0
# 4092       Hero Super Splendor 125cc    15244.0  Jaipur     40320.0
# ...                              ...        ...     ...         ...
# 189         Harley-Davidson Iron 883   435000.0  Jaipur      5550.0
# 2599      Harley-Davidson Street 750   445600.0  Jaipur      1500.0
# 7650                   Kawasaki Z650   478000.0  Jaipur      1234.0
# 9187  Harley-Davidson Street 750 ABS   520000.0  Jaipur       399.0
# 617           Suzuki Hayabusa 1300cc  1260000.0  Jaipur     17000.0
#
#              owner   age   power            brand
# 2696   First Owner  13.0   100.0             Hero
# ...

# %%
jaip.sort_values(by='price',ascending=False) #sorting data by price but in reverse order
# Out:
#                            bike_name      price    city  kms_driven  \
# 617           Suzuki Hayabusa 1300cc  1260000.0  Jaipur     17000.0
# 9187  Harley-Davidson Street 750 ABS   520000.0  Jaipur       399.0
# 7650                   Kawasaki Z650   478000.0  Jaipur      1234.0
# 2599      Harley-Davidson Street 750   445600.0  Jaipur      1500.0
# 189         Harley-Davidson Iron 883   435000.0  Jaipur      5550.0
# ...                              ...        ...     ...         ...
# 4092       Hero Super Splendor 125cc    15244.0  Jaipur     40320.0
# 2983              Bajaj CT 100 100cc    15000.0  Jaipur     48000.0
# 3365       Hero Super Splendor 125cc    15000.0  Jaipur     52391.0
# 9029              Hero Passion 100cc    14000.0  Jaipur     50000.0
# 2696         Hero Passion Plus 100cc    14000.0  Jaipur     70756.0
#
#              owner   age   power            brand
# 617    First Owner   4.0  1300.0           Suzuki
# ...

# %%
delhi=df[df["city"]=="Delhi"] ##filtering data
delhi
# Out:
#                                  bike_name     price   city  kms_driven  \
# 1              Royal Enfield Classic 350cc  119900.0  Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0  Delhi       110.0
# 5                         Yamaha FZs 150cc   53499.0  Delhi     25000.0
# 6            Honda CB Hornet 160R  ABS DLX   85000.0  Delhi      8200.0
# 7      Hero Splendor Plus Self Alloy 100cc   45000.0  Delhi     12645.0
# ...                                    ...       ...    ...         ...
# 9336                   Yamaha YZF-R3 320cc  220000.0  Delhi      7130.0
# 9338         Royal Enfield Himalayan 410cc  138000.0  Delhi      5000.0
# 9340                Honda CB Trigger 150cc   34400.0  Delhi     24513.0
# 9344  Royal Enfield Bullet Twinspark 350cc   80000.0  Delhi     56968.0
# 9362             Hero Hunk Rear Disc 150cc   25000.0  Delhi     48587.0
#
#              owner  age  power          brand
# 1      First Owner  4.0  350.0  Royal Enfield
# ...

# %%
delhi_top=delhi.sort_values(by="price",ascending=False) #sorting data

# %%
delhi_top["brand"].value_counts()
# Out:
# brand
# Bajaj              380
# Royal Enfield      305
# Hero               207
# Yamaha             145
# TVS                112
# Honda               95
# Suzuki              54
# KTM                 52
# Harley-Davidson     24
# Hyosung             12
# Mahindra            10
# Triumph              8
# Benelli              6
# Kawasaki             6
# Ducati               5
# BMW                  3
# MV                   1
# Rajdoot              1
# Name: count, dtype: int64

# %%
delhi_top.to_csv("Delhi_top.csv",index=False) ##creating a csv file to store filtered data.

# %%
df=pd.read_csv("Used_Bikes.csv") ##accessing csv file

# %%
df.isnull().sum() ##checks null values
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
import numpy as np

# %%
dt = {"A":[1,2,4,np.nan,5],
      "B":[7,4,np.nan,9,2],
      "C":[np.nan,8,7,5,6],
      "D":[7,4,1,2,5]}

# %%
df=pd.DataFrame(dt)
df
# Out:
#      A    B    C  D
# 0  1.0  7.0  NaN  7
# 1  2.0  4.0  8.0  4
# 2  4.0  NaN  7.0  1
# 3  NaN  9.0  5.0  2
# 4  5.0  2.0  6.0  5

# %%
df.dropna(axis="columns") # by default delete rows but by axis='columns' it will drop columns with none values.
# Out:
#    D
# 0  7
# 1  4
# 2  1
# 3  2
# 4  5

# %% [markdown]
# <h1 style="color:green; text-align:center">Thank You</h1>
